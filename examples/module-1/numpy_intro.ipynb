# %% [markdown]
# # Intro to Numpy

# %% [markdown]
# [Here](http://cs231n.github.io/python-numpy-tutorial/#python-sets) is a Numpy tutorial.

# %% [markdown]
# **Numpy** is the core library for scientific computing in Python. It provides a high-performance multidimensional array object, and tools for working with these arrays.
# A **numpy array** is a grid of values, all of the same type, and is indexed by a tuple of nonnegative integers. The number of dimensions is the **rank** of the array; the **shape** of an array is a tuple of integers giving the size of the array along each dimension.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Vectors

# %%
# A vector:
v = np.array([1,2,3])
v
# Out:
# array([1, 2, 3])

# %%
type(v)
# Out:
# numpy.ndarray

# %%
list(v)
# Out:
# [1, 2, 3]

# %%
v[0]
# Out:
# 1

# %%
# Dot product of two vectors:
w = np.array([100,10,1])

print(np.dot(v, w))
# Out:
# 123

# %% [markdown]
# ## Matrices

# %%
#A matrix:
m = np.array([[0,1],[2,3]])
m
# Out:
# array([[0, 1],
#        [2, 3]])

# %%
print(m)
# Out:
# [[0 1]
#  [2 3]]

# %%
m[1,1]
# Out:
# 3

# %%
m[1,1]=4
m
# Out:
# array([[0, 1],
#        [2, 4]])

# %%
print(m.shape)            #Dimension of the array
# Out:
# (2, 2)

# %%
b = np.array([[1,2,3],[4,5,6]])    # Create a rank 2 array
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
b.shape
# Out:
# (2, 3)

# %%
(b[0, 0], b[0, 1], b[1, 0])   # Prints "1 2 4"
# Out:
# (1, 2, 4)

# %%
#Matrix times vector:
m = np.array([[1,10],[100,1000]])
v = np.array([1,2])
np.dot(m, v)
# Out:
# array([  21, 2100])

# %%
#Matrix times matrix:
m1 = np.array([[1,2],[3,4],[5,6]])
m2 = np.array([[5,6],[7,8]])
np.dot(m1, m2)
# Out:
# array([[19, 22],
#        [43, 50],
#        [67, 78]])

# %% [markdown]
# ## Descriptive statistics

# %%
df = pd.read_csv('./GDP-2015.csv')
gdp = df['GDP per capita']

# %%
import numpy
print( "Mean GDP is", np.mean(gdp) )
print( "Standard deviation is", np.std(gdp) )
print( "Count is", np.count_nonzero(gdp) )
print( "Minimum GDP is", min(gdp) )
print( "Maximum GDP is", max(gdp) )
print( "25 percentile of GDP is", np.percentile(gdp, 25) )
print( "50 percentile of GDP is", np.percentile(gdp, 50) )
print( "75 percentile of GDP is", np.percentile(gdp, 75) )
print( "Sum is", np.sum(gdp) )
print( "Median is", np.median(gdp) )
# Out:
# Mean GDP is 18194.47619047619
# Standard deviation is 19192.237408635632
# Count is 168
# Minimum GDP is 605
# Maximum GDP is 139542
# 25 percentile of GDP is 3714.0
# 50 percentile of GDP is 11794.0
# 75 percentile of GDP is 25816.5
# Sum is 3056672
# Median is 11794.0

# %% [markdown]
# ## Random numbers

# %%
np.random.rand()
# Out:
# 0.4108630258549073

# %%
np.random.rand(10)
# Out:
# array([0.15589943, 0.73103266, 0.89095411, 0.33361803, 0.28150219,
#        0.50836106, 0.50964383, 0.95992614, 0.35281052, 0.14537124])
